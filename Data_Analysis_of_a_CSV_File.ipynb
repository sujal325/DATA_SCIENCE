# %%
import pandas as pd
import matplotlib as mlt

# %%
df = pd.read_csv("/content/iris.csv")

# %%
df_numeric = df.select_dtypes(include=['number'])
print(df_numeric)

# %%
mean_value = df_numeric.mean()
mode_value = df_numeric.mode()
median_value = df_numeric.median()
print(mean_value)
print(mode_value)
print(median_value)

# %%
df_numeric.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': '150'}>, <Axes: title={'center': '4'}>],
#        [<Axes: title={'center': 'setosa'}>,
#         <Axes: title={'center': 'versicolor'}>],
#        [<Axes: title={'center': 'virginica'}>, <Axes: >]], dtype=object)
